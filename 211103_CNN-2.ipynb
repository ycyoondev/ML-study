# %% [markdown]
# <a href="https://colab.research.google.com/github/ycyoondev/ML-study/blob/master/211103_CNN-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### CNN Case Study

# %% [markdown]
# 아래 그림은 최초의 CNN 모델이다.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 다음 그림은 이미지 분석 경진되에 1등을 통해 인기를 끌었던 모델이다.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)![image.png](data:image/png;base64,...)

# %% [markdown]
# 위에 Normalization layer는 최근들어 잘 사용되지 않는다. 최종적인 결과를 만들게 된다. 처음 ReLU를 사용한 모델이다.

# %% [markdown]
# 다음으로 구글에서 사용한 이미지 분류 모델이다.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2015년에 나온 ResNet은 사람의 정확도를 넘어선 모델이다. 이미지 분류 말고도 여러가지 모델에서 좋은 성능을 만든 모델이다.
#
# 이때 학습층의 깊이를 매우 높게 잡은것이 특징이다. Residual net을 사용하여 학습 시간을 관리한 모델이다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
