# %% [markdown]
# Hypothesis

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

x_train = torch.FloatTensor([[1], [2], [3]]) #training data
y_train = torch.FloatTensor([[2], [4], [6]])

# %%
W = torch.zeros(1, requires_grad=True) #0으로 초기화 후 학습할 것이라고 명시
b = torch.zeros(1, requires_grad=True)

# %%
cost = torch.mean((hypothesis - y_train) ** 2) #가설의 값과 결과의 차이가 cost가 된다

# %%
optimizer = optim.SGD([W, b], lr=0.01) # lr=0.01은 learnign rate

nb_epochs = 1000
for epoch in range(1, nb_epochs + 1):
  hypothesis = x_train * W + b
  cost = torch.mean((hypothesis - y_train) ** 2) #가설의 값과 결과의 차이가 cost가 된다

  optimizer.zero_grad() #gradient 초기화
  cost.backward() #gradient 계산
  optimizer.step()

# %% [markdown]
# # 새 섹션

# %%
print(W, b)
# Out:
# tensor([1.9709], requires_grad=True) tensor([0.0663], requires_grad=True)
